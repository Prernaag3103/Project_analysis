# %% [markdown]
# # Case Study: Analysis of Bellabeat, a high-tech company that manufactures health-focused smart products.

# %% [markdown]
# ### **Author: Prerna Agarwal Last Updated: 12 Feb 2022**

# %% [markdown]
# This case study is a part of [Google Data Analytics Professional Certificate](https://www.coursera.org/professional-certificates/google-data-analytics) capstone project. In this case study I used the data which is publicly available on Kaggle: FitBit Fitness Tracker Data in order to answer the key business questions and will follow the steps of the data analysis process: ask, prepare, process, analyze, share, and act.

# %% [markdown]
# **Scenario**
#
# I am a junior data analyst working on the marketing analyst team at Bellabeat, a high-tech manufacturer of health-focused
# products for women. The cofounder and Chief Creative Officer of Bellabeat, believes that analyzing smart
# device fitness data could help unlock new growth opportunities for the company. I have been asked to focus on one of
# Bellabeat’s products and analyze smart device data to gain insight into how consumers are using their smart devices. The
# insights I discover will then help guide marketing strategy for the company.

# %% [markdown]
# **Key Business Task**
#
# Need to analyze smart device usage data in order to gain insight into how consumers use non-Bellabeat smart
# devices. I have selected one Bellabeat product to apply these insights in my presentation.
#
# **Starting points will be:**
# 1. Identifying some trends in smart device usage.
# 2. Using these trends apply to Bellabeat customers.
# 3. Use these trends to influence Bellabeat marketing strategy.

# %% [markdown]
# **Key Stakeholders**
# 1. Urška Sršen — Bellabeat’s cofounder and Chief Creative Officer.
# 2. Sando Mur — Mathematician and Bellabeat’s cofounder; key member of the Bellabeat executive team

# %% [markdown]
# ### **Prepare the data**

# %% [markdown]
# **About the dataset**
#
# -Data used in analysis is [FitBit Fitness Tracker Data](https://www.kaggle.com/arashnic/fitbit) made available by Mobius stored on Kaggle.
#
# -This dataset is under CC0: Public Domain license meaning the creator has waive his right to the work under the copyright law.
#
# -This Kaggle data set contains personal fitness tracker from thirty fitbit users. Thirty eligible Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. It includes information about daily activity, steps, and heart rate that can be used to explore users’ habits.
#
# -These datasets were generated by respondents to a distributed survey via Amazon Mechanical Turk.
# Comprehensive: MEDIUM
# Current: LOW: data is 5 years old
# Cited: HIGH: Data is well documentedbetween 03.12.2016-05.12.2016.
#
# **ROCCC analysis**
#
# - Reliability: LOW: dataset was collected from 30 individuals whose gender is unknown and sample is less.
# - Originality: LOW: Data was collected by third party via Amazon Mechanical Turk.
# - Comprehensive: MEDIUM
# - Current: LOW: data is 5 years old
# - Cited: HIGH: Data is well documented

# %% [markdown]
# **Selecting data**
#
# Focus is on daily usage of the Fitbit device as it should provide a high-level insight on the usage pattern of smart devices. Thus the following files from the dataset has been selected:
#
# * dailyActivity_merged.csv
# * dailyCalories_merged.csv
# * dailyIntensities_merged.csv
# * dailySteps_merged.csv
# * sleepDay_merged.csv
# * weightLogInfo_merged.csv

# %% [markdown]
# ### Process the data

# %% [markdown]
# MS Excel spreadsheet will be used to process the data as the tool functionality fits the purpose.
#
# **Cleaning data**
#
# The date column has been selected and formatted to date and removed timestamp as it is not required for analysis.

# %% [markdown]
# R Studio was used to complete this analysis because of the many packages and data visualization features available to explore the data with.

# %% [markdown]
# #### Installing and loading of packages:

# %%
install.packages("tidyverse")
# Out:
# also installing the dependency 'jsonlite'
#   There is a binary version available but the source version is later:
#          binary source needs_compilation
# jsonlite  1.7.2  1.7.3              TRUE
#
#   Binaries will be installed
# package 'jsonlite' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'jsonlite'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\prern\anaconda3\envs\Rprogram\Lib\R\library\00LOCK\jsonlite\libs\x64\jsonlite.dll to C:\Users\prern\anaconda3\envs\Rprogram\Lib\R\library\jsonlite\libs\x64\jsonlite.dll: Permission denied"Warning message:
# "restored 'jsonlite'"
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prern\AppData\Local\Temp\RtmpUBgLyz\downloaded_packages

# %%
install.packages("here")
install.packages("skimr")
install.packages("janitor")
install.packages("dplyr")
library("tidyverse")
library("here")
library("skimr")
library("janitor")
library("dplyr")
# Out:
# also installing the dependency 'rprojroot'
# package 'rprojroot' successfully unpacked and MD5 sums checked
# package 'here' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prern\AppData\Local\Temp\RtmpUBgLyz\downloaded_packages
# package 'skimr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prern\AppData\Local\Temp\RtmpUBgLyz\downloaded_packages
# also installing the dependency 'snakecase'
# package 'snakecase' successfully unpacked and MD5 sums checked
# package 'janitor' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prern\AppData\Local\Temp\RtmpUBgLyz\downloaded_packages
# also installing the dependency 'rlang'
#   There are binary versions available but the source versions are later:
#       binary source needs_compilation
# rlang 0.4.11  1.0.1              TRUE
# dplyr  1.0.6  1.0.8              TRUE
#
# ...

# %% [markdown]
# **Importing datasets**

# %%
install.packages("hms")
# Out:
#   There is a binary version available but the source version is later:
#     binary source needs_compilation
# hms  1.0.0  1.1.1             FALSE
# installing the source package 'hms'

# %%
setwd("C:/Users/prern/Downloads")
daily_activity<-read.csv("dailyactivities_merged.csv")
daily_calories<-read.csv("dailycalories_merged.csv")
daily_intensities<-read.csv("dailyintensities_merged.csv")
daily_steps<-read.csv("dailysteps_merged.csv")
sleep_day<-read.csv("sleepday_merged.csv")
weight_log<-read.csv("weightloginfo_merged.csv")

# %% [markdown]
# ### Viewing the data frames:

# %% [markdown]
# To ensure the data frames were imported correctly, the head() function is used. The colnames() and glimpse() functions were used to explore the data frames and find commonalities.
#
# ### *daily_activity*

# %%
head(daily_activity)
# Out:
#   Id         ActivityDate TotalSteps TotalDistance TrackerDistance
# 1 1503960366 12-04-2016   13162      8.50          8.50
# 2 1624580081 12-04-2016    8163      5.31          5.31
# 3 1644430081 12-04-2016   10694      7.77          7.77
# 4 1844505072 12-04-2016    6697      4.43          4.43
# 5 1927972279 12-04-2016     678      0.47          0.47
# 6 2022484408 12-04-2016   11875      8.34          8.34
#   LoggedActivitiesDistance VeryActiveDistance ModeratelyActiveDistance
# 1 0                        1.88               0.55
# 2 0                        0.00               0.00
# 3 0                        0.14               2.30
# 4 0                        0.00               0.00
# 5 0                        0.00               0.00
# 6 0                        3.31               0.77
#   LightActiveDistance SedentaryActiveDistance VeryActiveMinutes
# 1 6.06                0                       25
# 2 5.31                0                        0
# ...

# %%
colnames(daily_activity)
# Out:
#  [1] "Id"                       "ActivityDate"
#  [3] "TotalSteps"               "TotalDistance"
#  [5] "TrackerDistance"          "LoggedActivitiesDistance"
#  [7] "VeryActiveDistance"       "ModeratelyActiveDistance"
#  [9] "LightActiveDistance"      "SedentaryActiveDistance"
# [11] "VeryActiveMinutes"        "FairlyActiveMinutes"
# [13] "LightlyActiveMinutes"     "SedentaryMinutes"
# [15] "Calories"

# %% [markdown]
# ### *daily_calories*

# %%
head(daily_calories)
# Out:
#   Id         ActivityDay Calories
# 1 1503960366 12-04-2016  1985
# 2 1624580081 12-04-2016  1432
# 3 1644430081 12-04-2016  3199
# 4 1844505072 12-04-2016  2030
# 5 1927972279 12-04-2016  2220
# 6 2022484408 12-04-2016  2390

# %%
colnames(daily_calories)
# Out:
# [1] "Id"          "ActivityDay" "Calories"

# %% [markdown]
# ### *daily_intensities*

# %%
head(daily_intensities)
# Out:
#   Id         ActivityDay SedentaryMinutes LightlyActiveMinutes
# 1 1503960366 12-04-2016   728             328
# 2 1624580081 12-04-2016  1294             146
# 3 1644430081 12-04-2016  1131             256
# 4 1844505072 12-04-2016  1101             339
# 5 1927972279 12-04-2016   734              55
# 6 2022484408 12-04-2016  1157             227
#   FairlyActiveMinutes VeryActiveMinutes SedentaryActiveDistance
# 1 13                  25                0
# 2  0                   0                0
# 3 51                   2                0
# 4  0                   0                0
# 5  0                   0                0
# 6 14                  42                0
#   LightActiveDistance ModeratelyActiveDistance VeryActiveDistance
# 1 6.06                0.55                     1.88
# 2 5.31                0.00                     0.00
# 3 5.33                2.30                     0.14
# 4 4.43                0.00                     0.00
# ...

# %%
colnames(daily_intensities)
# Out:
#  [1] "Id"                       "ActivityDay"
#  [3] "SedentaryMinutes"         "LightlyActiveMinutes"
#  [5] "FairlyActiveMinutes"      "VeryActiveMinutes"
#  [7] "SedentaryActiveDistance"  "LightActiveDistance"
#  [9] "ModeratelyActiveDistance" "VeryActiveDistance"

# %% [markdown]
# ### *daily_steps*

# %%
head(daily_steps)
# Out:
#   Id         ActivityDay StepTotal
# 1 1503960366 12-04-2016  13162
# 2 1624580081 12-04-2016   8163
# 3 1644430081 12-04-2016  10694
# 4 1844505072 12-04-2016   6697
# 5 1927972279 12-04-2016    678
# 6 2022484408 12-04-2016  11875

# %%
colnames(daily_steps)
# Out:
# [1] "Id"          "ActivityDay" "StepTotal"

# %% [markdown]
# ### *sleep_day*

# %%
head(sleep_day)
# Out:
#   Id         SleepDay   TotalSleepRecords TotalMinutesAsleep TotalTimeInBed
# 1 1503960366 05-01-2016 1                 369                396
# 2 1844505072 05-01-2016 1                 590                961
# 3 2026352035 05-01-2016 1                 527                546
# 4 3977333714 05-01-2016 1                 383                626
# 5 4319703577 05-01-2016 1                 484                500
# 6 4388161847 05-01-2016 1                 547                597

# %%
colnames(sleep_day)
# Out:
# [1] "Id"                 "SleepDay"           "TotalSleepRecords"
# [4] "TotalMinutesAsleep" "TotalTimeInBed"

# %% [markdown]
# ### *weight_log*

# %%
head(weight_log)
# Out:
#   Id         Date       WeightKg WeightPounds Fat BMI   IsManualReport LogId
# 1 8877689391 05-01-2016 85.3     188.0543     NA  25.53 FALSE          1.46e+12
# 2 4558609924 05-01-2016 69.9     154.1031     NA  27.32  TRUE          1.46e+12
# 3 6962181067 05-01-2016 61.7     136.0252     NA  24.10  TRUE          1.46e+12
# 4 1503960366 05-02-2016 52.6     115.9631     22  22.65  TRUE          1.46e+12
# 5 4558609924 05-02-2016 69.2     152.5599     NA  27.04  TRUE          1.46e+12
# 6 6962181067 05-02-2016 61.5     135.5843     NA  24.00  TRUE          1.46e+12

# %%
colnames(weight_log)
# Out:
# [1] "Id"             "Date"           "WeightKg"       "WeightPounds"
# [5] "Fat"            "BMI"            "IsManualReport" "LogId"

# %% [markdown]
# ### Removing data frames:

# %% [markdown]
# All six of the data frames contain the “Id” column, so it is possible to merge all of them if needed. The daily_activity data frame appears to contain data for calories, intensities, and steps. In order to use the daily_activity frame in place of daily_calories, daily_intensities, and daily_steps, the number of observations must be the same and the observations must match for each ID number.
#
# The sqldf package is loaded to utilize SQL syntax to determine if the values of daily_calories, daily_intensities, and daily_steps are contained in daily_activity. However, the number of columns must be the same between the data frames, so a temporary data frame with the important columns is created first.

# %% [markdown]
# When verified we get that the number of observations for each SQL data frame are equal to 940 and all output data frames head() function matches the original data frames. It can be concluded that the data for the daily_calories, daily_intensities, and daily_steps data frames are contained in daily_activity. These three data frames will be removed from the analysis to make it easier.

# %% [markdown]
# ### Analyzing the data:

# %% [markdown]
# Summarising the data:

# %%
n_distinct(daily_activity) #this function is used to determine the number of unique values
# Out:
# [1] 940

# %%
n_distinct(sleep_day)
# Out:
# [1] 410

# %%
n_distinct(weight_log)
# Out:
# [1] 67

# %%
nrow(daily_activity) #this function is used to number of rows in a data frame
# Out:
# [1] 940

# %%
nrow(sleep_day)
# Out:
# [1] 413

# %%
nrow(weight_log)
# Out:
# [1] 67

# %% [markdown]
# Weight_log data frame has less amount of data, so it is not reliable and we can't make recommendations using the same.

# %% [markdown]
# ### *daily_activity*

# %%
daily_activity %>%
select(TotalSteps,TotalDistance, SedentaryMinutes, LightlyActiveMinutes, FairlyActiveMinutes, VeryActiveMinutes, Calories)%>%
summary() # summary() function is used to pull key statistics about the data frames.
# Out:
#    TotalSteps    TotalDistance    SedentaryMinutes LightlyActiveMinutes
#  Min.   :    0   Min.   : 0.000   Min.   :   0.0   Min.   :  0.0
#  1st Qu.: 3790   1st Qu.: 2.620   1st Qu.: 729.8   1st Qu.:127.0
#  Median : 7406   Median : 5.245   Median :1057.5   Median :199.0
#  Mean   : 7638   Mean   : 5.490   Mean   : 991.2   Mean   :192.8
#  3rd Qu.:10727   3rd Qu.: 7.713   3rd Qu.:1229.5   3rd Qu.:264.0
#  Max.   :36019   Max.   :28.030   Max.   :1440.0   Max.   :518.0
#  FairlyActiveMinutes VeryActiveMinutes    Calories
#  Min.   :  0.00      Min.   :  0.00    Min.   :   0
#  1st Qu.:  0.00      1st Qu.:  0.00    1st Qu.:1828
#  Median :  6.00      Median :  4.00    Median :2134
#  Mean   : 13.56      Mean   : 21.16    Mean   :2304
#  3rd Qu.: 19.00      3rd Qu.: 32.00    3rd Qu.:2793
#  Max.   :143.00      Max.   :210.00    Max.   :4900

# %% [markdown]
# ### *sleep_day*

# %%
sleep_day %>%
select(TotalSleepRecords, TotalMinutesAsleep, TotalTimeInBed)%>%
summary()
# Out:
#  TotalSleepRecords TotalMinutesAsleep TotalTimeInBed
#  Min.   :1.000     Min.   : 58.0      Min.   : 61.0
#  1st Qu.:1.000     1st Qu.:361.0      1st Qu.:403.0
#  Median :1.000     Median :433.0      Median :463.0
#  Mean   :1.119     Mean   :419.5      Mean   :458.6
#  3rd Qu.:1.000     3rd Qu.:490.0      3rd Qu.:526.0
#  Max.   :3.000     Max.   :796.0      Max.   :961.0

# %% [markdown]
# ### *weight_log*

# %%
weight_log%>%
select(WeightPounds, BMI)%>%
summary()
# Out:
#   WeightPounds        BMI
#  Min.   :116.0   Min.   :21.45
#  1st Qu.:135.4   1st Qu.:23.96
#  Median :137.8   Median :24.39
#  Mean   :158.8   Mean   :25.19
#  3rd Qu.:187.5   3rd Qu.:25.56
#  Max.   :294.3   Max.   :47.54

# %% [markdown]
# ## Share

# %% [markdown]
# I have used ggplot() function to create visualizations to indentify trends and patterns in the data.

# %%
install.packages("ggplot2")
# Out:
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# ggplot2  3.3.3  3.3.5             FALSE
# installing the source package 'ggplot2'

# %%
library(ggplot2)

# %%
df<- as.data.frame(daily_activity)

df%>%
ggplot(aes(x=VeryActiveMinutes, y=Calories)) + geom_point() + stat_smooth(method= lm)+ labs(title="Relationship between VeryActiveMinutes and Calories burned")
## 'geom_smooth' using formula y~x
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# This graph shows positive relation between the VeryActiveMinutes and Calories, so the more active the person is, more calories are burned.

# %%
df%>%
ggplot(aes(x=TotalDistance, y=Calories)) + geom_smooth()+ labs(title= "Relationship between Total Distance and Calories burned")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# This graph also shows the positive relation between Total Distance travelled and Calories burned. So,they are directly proportional to each other.

# %%
df%>%
ggplot(aes(x= TotalSteps, y= Calories)) + geom_point()+ stat_smooth(method=lm) + labs(title= "Relationship between Total 
steps and Calories burned")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# This graph also shows the positive relation between Total steps taken and Calories burned, they are directly proportional to each other.

# %%
ggplot(data=sleep_day, aes(x=TotalMinutesAsleep, y=TotalTimeInBed)) + geom_point() + stat_smooth(method=lm)+ labs(title= 
"Relationship between Total minutes in bed and Total time in bed")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# This graph also shows positive relation between the two taken variables. Most of the time people spent asleep and the time they spent in bed is similar.

# %% [markdown]
# ## Act:

# %% [markdown]
# ### **Recommendations for Bellabeat business:**
#
# 1. Bellabeat can introduce an alert function in the app which can timely notify users who tends to have high sedentary minutes.
# 2. Bellabeat app can offer reduce subscription prices for users who meet the health and fitness targets.
# 3. Company can offer free trial subscriptions to increase the footprint.
# 4. App can introduce alerts to meet the daily steps and calories targets.
# 5. Bellabeat marketing team can encourage users by educating them about the health and fitness benefits, also can provide information about calories intake and exercises.
